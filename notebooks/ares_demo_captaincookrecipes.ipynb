# %%
import sys
import os
ROOT_DIR = '..'
sys.path.append(os.path.join(ROOT_DIR, 'src'))

import os
import sys

# %%
with open(f"{ROOT_DIR}/API_KEY.txt", "r") as file:
    api_key = file.read().strip()

os.environ['OPENAI_API_KEY'] = api_key
# os.environ['CACHE_DIR'] = os.path.join(ROOT_DIR, 'cache_dir')

# %%
data_name = 'recipe_graph3'
method_name = 'cert_granular_temp0_nonexact'
cache = True
split = 'val'
# model_name = 'qwen2.5-7b-instruct'
# model_name = 'phi-4'
model_name = 'gpt-4o-mini'
# model_name = 'gpt-4.1-mini'
p = 0.95
debug = True
suffix = '.no_cot'

# %% [markdown]
# # Experiment Config

# %%
# Possible Configs
# exp_name = 'eb1_simple', 'eb1_overcomplete' etc.
# Inside the config:
# task (eb1, eb2, eb3, nsf_scify): str
# overcomplete: bool
import importlib
import exp_helpers
importlib.reload(exp_helpers)
from exp_helpers.exp_configs import DATA_CONFIGS, METHOD_CONFIGS, MODEL_CONFIGS


data_config = DATA_CONFIGS[data_name]
method_config = METHOD_CONFIGS[method_name]
model_config = MODEL_CONFIGS[model_name]

results_dir = os.path.join(
    ROOT_DIR, 
    'results',
    'stability_rate', 
    f'{data_name}.{split}.{model_name}.{method_name}.p{p}{suffix}'
)
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# # Load data

# %%
from exp_helpers.datasets import get_dataset
# Out:
# [nltk_data] Downloading package punkt to /home/runai-home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /home/runai-home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /home/runai-home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /home/runai-home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /home/runai-home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /home/runai-home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Assuming data is in mythbusters/data/scify
dataset = get_dataset(data_config, split, root_dir=ROOT_DIR)

# %%
len(dataset)
# Out:
# 1000

# %%
dataset[0]['raw_claims'], dataset[0]['derived_claims']
# Out:
# (['We have pepper.',
#   'We have garlic.',
#   'We have onion.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Peel-Peel 1 garlic clove.',
#   'Only after the necessary preceding steps (Stir-Stir the contents in the microwave with a spoon), And if we have all the ingredients, we can then Microwave-Microwave the plate, covered, on high for 1.5 minutes.',
#   'Only after the necessary preceding steps (Cut-Cut 1/8 garlic clove), And if we have all the ingredients, we can then Mince-Mince 1/8 garlic clove.',
#   'Only after the necessary preceding steps (Mix-Mix 1/4 cup sweet-and-sour sauce and 1/2 teaspoon soy sauce in a small bowl, and Top-Top the plate with the carrots, onion, garlic and 1/4 tsp pepper powder), And if we have all the ingredients, we can then Pour-Pour the sauces over the meatballs.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Cut-Cut 1/4 medium carrot into short, thin strips.',
#   'Only after the necessary preceding steps (Peel-Peel 1 garlic clove), And if we have all the ingredients, we can then Cut-Cut 1/8 garlic clove.',
#   'Only after the necessary preceding steps (Microwave-Microwave for 1 more minute), And if we have all the ingredients, we can then END.',
#   'Only after the necessary preceding steps (Place-Place 5 meatballs in a Microwave-safe plate, and Cut-Cut 1/4 medium carrot into short, thin strips, and Slice-Slice 1/8 medium onion, and Mince-Mince 1/8 garlic clove), And if we have all the ingredients, we can then Top-Top the plate with the carrots, onion, garlic and 1/4 tsp pepper powder.',
#   'Only after the necessary preceding steps (Peel-Peel one medium onion), And if we have all the ingredients, we can then cut-Cut onion into two pieces.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Place-Place 5 meatballs in a Microwave-safe plate.',
#   'Only after the necessary preceding steps (Pour-Pour the sauces over the meatballs), And if we have all the ingredients, we can then Microwave-Microwave the plate, covered, on high for 1.5 minutes.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Peel-Peel one medium onion.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Mix-Mix 1/4 cup sweet-and-sour sauce and 1/2 teaspoon soy sauce in a small bowl.',
#   'Only after the necessary preceding steps (cut-Cut onion into two pieces), And if we have all the ingredients, we can then Slice-Slice 1/8 medium onion.',
#   'Only after the necessary preceding steps (Stir-Stir the contents in the microwave with a spoon), And if we have all the ingredients, we can then Microwave-Microwave for 1 more minute.',
#   'Only after the necessary preceding steps (Microwave-Microwave the plate, covered, on high for 1.5 minutes), And if we have all the ingredients, we can then Stir-Stir the contents in the microwave with a spoon.',
#   'We have garlic clove.',
#   'Only after the necessary preceding steps (Microwave-Microwave the plate, covered, on high for 1.5 minutes), And if we have all the ingredients, we can then Stir-Stir the contents in the microwave with a spoon.',
#   'We now START.'],
#  ['Because we have completed all previous steps (START), and have all necessary ingredients (garlic clove), we can now do the step Peel-Peel 1 garlic clove. And now we have completed this step Peel-Peel 1 garlic clove.',
#   'Because we have completed all previous steps (START), and have all necessary ingredients (onion), we can now do the step Peel-Peel one medium onion. And now we have completed this step Peel-Peel one medium onion.',
#   'Because we have completed all previous steps (START),  we can now do the step Place-Place 5 meatballs in a Microwave-safe plate. And now we have completed this step Place-Place 5 meatballs in a Microwave-safe plate.',
#   'Because we have completed all previous steps (START), and have all necessary ingredients (medium carrot), we can now do the step Cut-Cut 1/4 medium carrot into short, thin strips. And now we have completed this step Cut-Cut 1/4 medium carrot into short, thin strips.',
#   'Because we have completed all previous steps (START),  we can now do the step Mix-Mix 1/4 cup sweet-and-sour sauce and 1/2 teaspoon soy sauce in a small bowl. And now we have completed this step Mix-Mix 1/4 cup sweet-and-sour sauce and 1/2 teaspoon soy sauce in a small bowl.',
#   'Because we have completed all previous steps (Peel-Peel 1 garlic clove), and have all necessary ingredients (garlic clove), we can now do the step Cut-Cut 1/8 garlic clove. And now we have completed this step Cut-Cut 1/8 garlic clove.',
#   'Because we have completed all previous steps (Peel-Peel one medium onion), and have all necessary ingredients (onion), we can now do the step cut-Cut onion into two pieces. And now we have completed this step cut-Cut onion into two pieces.',
#   'Because we have completed all previous steps (Cut-Cut 1/8 garlic clove), and have all necessary ingredients (garlic clove), we can now do the step Mince-Mince 1/8 garlic clove. And now we have completed this step Mince-Mince 1/8 garlic clove.',
#   'Because we have completed all previous steps (cut-Cut onion into two pieces), and have all necessary ingredients (1/8 medium onion), we can now do the step Slice-Slice 1/8 medium onion. And now we have completed this step Slice-Slice 1/8 medium onion.',
#   'Because we have completed all previous steps (Place-Place 5 meatballs in a Microwave-safe plate, and Cut-Cut 1/4 medium carrot into short, thin strips, and Slice-Slice 1/8 medium onion, and Mince-Mince 1/8 garlic clove), and have all necessary ingredients (carrots, and onion, and garlic, and pepper), we can now do the step Top-Top the plate with the carrots, onion, garlic and 1/4 tsp pepper powder. And now we have completed this step Top-Top the plate with the carrots, onion, garlic and 1/4 tsp pepper powder.',
#   'Because we have completed all previous steps (Mix-Mix 1/4 cup sweet-and-sour sauce and 1/2 teaspoon soy sauce in a small bowl, and Top-Top the plate with the carrots, onion, garlic and 1/4 tsp pepper powder),  we can now do the step Pour-Pour the sauces over the meatballs. And now we have completed this step Pour-Pour the sauces over the meatballs.',
#   'Because we have completed all previous steps (Pour-Pour the sauces over the meatballs),  we can now do the step Microwave-Microwave the plate, covered, on high for 1.5 minutes. And now we have completed this step Microwave-Microwave the plate, covered, on high for 1.5 minutes.',
#   'Because we have completed all previous steps (Microwave-Microwave the plate, covered, on high for 1.5 minutes),  we can now do the step Stir-Stir the contents in the microwave with a spoon. And now we have completed this step Stir-Stir the contents in the microwave with a spoon.',
#   'Because we have completed all previous steps (Stir-Stir the contents in the microwave with a spoon),  we can now do the step Microwave-Microwave the plate, covered, on high for 1.5 minutes. And now we have completed this step Microwave-Microwave the plate, covered, on high for 1.5 minutes.',
#   'Because we have completed all previous steps (Microwave-Microwave the plate, covered, on high for 1.5 minutes),  we can now do the step Stir-Stir the contents in the microwave with a spoon. And now we have completed this step Stir-Stir the contents in the microwave with a spoon.',
#   'Because we have completed all previous steps (Stir-Stir the contents in the microwave with a spoon),  we can now do the step Microwave-Microwave for 1 more minute. And now we have completed this step Microwave-Microwave for 1 more minute.',
#   'Because we have completed all previous steps (Microwave-Microwave for 1 more minute),  we can now do the step END. And now we have completed this step END.'])

# %%
di = 1
dataset[di]['raw_claims'], dataset[di]['derived_claims']
# Out:
# (['We have corn.',
#   'Only after the necessary preceding steps (Mix-Mix the contents of the bowl well), And if we have all the ingredients, we can then END.',
#   'Only after the necessary preceding steps (Measure-Measure 2 cups of frozen corn), And if we have all the ingredients, we can then Thaw-Thaw the frozen corn by putting it in a sieve and running it under cold water.',
#   'We have lime.',
#   'Only after the necessary preceding steps (Microwave-Microwave the corn for 3 more minutes), And if we have all the ingredients, we can then Add-Add 1 teaspoon salt to the bowl.',
#   'Only after the necessary preceding steps (Microwave-Microwave the corn for 3 more minutes, and Extract-Extract lime juice from 1/3 lime), And if we have all the ingredients, we can then add-add lime juice to the bowl.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Measure-Measure 2 cups of frozen corn.',
#   'Only after the necessary preceding steps (Add-Add 1 teaspoon salt to the bowl, and add-add lime juice to the bowl), And if we have all the ingredients, we can then Mix-Mix the contents of the bowl well.',
#   'Only after the necessary preceding steps (START), And if we have all the ingredients, we can then Extract-Extract lime juice from 1/3 lime.',
#   'Only after the necessary preceding steps (stir-then stir the bowl), And if we have all the ingredients, we can then Microwave-Microwave the corn for 3 more minutes.',
#   'Only after the necessary preceding steps (Add-Add the corn into a microwave-safe bowl), And if we have all the ingredients, we can then Microwave-Microwave the corn for 2 minutes.',
#   'Only after the necessary preceding steps (Microwave-Microwave the corn for 2 minutes), And if we have all the ingredients, we can then Add-Add 1 teaspoon of softened butter.',
#   'We have pepper.',
#   'Only after the necessary preceding steps (Add-1 teaspoon of pepper powder to the bowl, and Add-Add 1 teaspoon of softened butter), And if we have all the ingredients, we can then stir-then stir the bowl.',
#   'We have salt.',
#   'Only after the necessary preceding steps (Thaw-Thaw the frozen corn by putting it in a sieve and running it under cold water), And if we have all the ingredients, we can then Add-Add the corn into a microwave-safe bowl.',
#   'Only after the necessary preceding steps (Microwave-Microwave the corn for 2 minutes), And if we have all the ingredients, we can then Add-1 teaspoon of pepper powder to the bowl.',
#   'We now START.'],
#  ['Because we have completed all previous steps (START), and have all necessary ingredients (corn), we can now do the step Measure-Measure 2 cups of frozen corn. And now we have completed this step Measure-Measure 2 cups of frozen corn.',
#   'Because we have completed all previous steps (START), and have all necessary ingredients (lime), we can now do the step Extract-Extract lime juice from 1/3 lime. And now we have completed this step Extract-Extract lime juice from 1/3 lime.',
#   'Because we have completed all previous steps (Measure-Measure 2 cups of frozen corn),  we can now do the step Thaw-Thaw the frozen corn by putting it in a sieve and running it under cold water. And now we have completed this step Thaw-Thaw the frozen corn by putting it in a sieve and running it under cold water.',
#   'Because we have completed all previous steps (Thaw-Thaw the frozen corn by putting it in a sieve and running it under cold water), and have all necessary ingredients (corn), we can now do the step Add-Add the corn into a microwave-safe bowl. And now we have completed this step Add-Add the corn into a microwave-safe bowl.',
#   'Because we have completed all previous steps (Add-Add the corn into a microwave-safe bowl), and have all necessary ingredients (corn), we can now do the step Microwave-Microwave the corn for 2 minutes. And now we have completed this step Microwave-Microwave the corn for 2 minutes.',
#   'Because we have completed all previous steps (Microwave-Microwave the corn for 2 minutes), and have all necessary ingredients (pepper), we can now do the step Add-1 teaspoon of pepper powder to the bowl. And now we have completed this step Add-1 teaspoon of pepper powder to the bowl.',
#   'Because we have completed all previous steps (Microwave-Microwave the corn for 2 minutes), and have all necessary ingredients (butter), we can now do the step Add-Add 1 teaspoon of softened butter. And now we have completed this step Add-Add 1 teaspoon of softened butter.',
#   'Because we have completed all previous steps (Add-1 teaspoon of pepper powder to the bowl, and Add-Add 1 teaspoon of softened butter),  we can now do the step stir-then stir the bowl. And now we have completed this step stir-then stir the bowl.',
#   'Because we have completed all previous steps (stir-then stir the bowl), and have all necessary ingredients (corn), we can now do the step Microwave-Microwave the corn for 3 more minutes. And now we have completed this step Microwave-Microwave the corn for 3 more minutes.',
#   'Because we have completed all previous steps (Microwave-Microwave the corn for 3 more minutes, and Extract-Extract lime juice from 1/3 lime), and have all necessary ingredients (lime), we can now do the step add-add lime juice to the bowl. And now we have completed this step add-add lime juice to the bowl.',
#   'Because we have completed all previous steps (Microwave-Microwave the corn for 3 more minutes), and have all necessary ingredients (salt), we can now do the step Add-Add 1 teaspoon salt to the bowl. And now we have completed this step Add-Add 1 teaspoon salt to the bowl.',
#   'Because we have completed all previous steps (Add-Add 1 teaspoon salt to the bowl, and add-add lime juice to the bowl),  we can now do the step Mix-Mix the contents of the bowl well. And now we have completed this step Mix-Mix the contents of the bowl well.',
#   'Because we have completed all previous steps (Mix-Mix the contents of the bowl well),  we can now do the step END. And now we have completed this step END.'])

# %%
# TODO: add to the end of the base claims: "Is claim {claim} scientifically feasible, where scientifically feasible means XXX?"
# At the very end of derived claim, there should be another claim added: "Therefore, the claim {claim} is {mapping[likert]}"

# %% [markdown]
# # Load Model

# %%
from exp_helpers.models import get_llm, EntailmentModel
# Out:
# INFO 01-12 19:10:28 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 01-12 19:10:28 [__init__.py:239] Automatically detected platform cuda.

# %%
llm = get_llm(**model_config)
entailment_model = EntailmentModel(llm=llm, max_new_tokens=1000)

# %% [markdown]
# # Generate Entailment Prob

# %%
entailment_mode = entailment_model.create_custom_config(
    system_prompt = """
You are an expert judge for evaluating entailment. Given claims/reasoning chain as evidence and a hypothesis, determine if all the claims together supports that hypothesis is correct. 

The hypothesis is entailed if it can be derived from the premises.
For the hypothesis, please first make your reasoning about what is the precondition the hypothesis is (which clues or what previously derived results it uses etc.), and what conclusion it is making based on the precondition.
If the hypothesis says it is only use particular rules, then you should only make the judgement based on those clues, without relying on other previously stated claims, even if having access to those claims allows you to reach the conclusion.
Please only say it is entailed if the both the precondition and the logical derivation of the conclusion based on the precondition are correct.
Provide your judgment as one of the following: "Very Likely", "Likely", "Somewhat Likely", "Neutral", "Somewhat Unlikely", "Unlikely", "Very Unlikely", where Very Likely means the hypothesis is very likely to be entailed (given the premise), and Very Unlikely means that the hypothesis contradicts to some premise logically.
If there are certain ingredients needed in the hypothesis that are not in the premise, then it should be Very Unlikely.
If there are certain previous steps that need to be completed before doing the step in the hypothesis, and that step is not completed, then it should also be Very Unlikely.

Input format:
Context:
<claims as evidence>

Hypothesis
<hypothesis claim>

The output format must be one of the following without additional words:
Very Likely/Likely/Somewhat Likely/Neutral/Somewhat Unlikely/Unlikely/Very Unlikely
""",
    mapping = {
        'Very Likely': 1.0,
        'Likely': 0.8,
        'Somewhat Likely': 0.6,
        'Neutral': 0.5,
        'Somewhat Unlikely': 0.4,
        'Unlikely': 0.2,
        'Very Unlikely': 0.0
    },
    field_name='Entailment',
    default_value='Neutral'
)

method_config['kwargs']['entailment_mode'] = entailment_mode

# %%
from exp_helpers.methods import get_stability_scorer

stability_scorer = get_stability_scorer(method_config['method'], entailment_model, p, **method_config['kwargs'])

# %%
results_dir
# Out:
# '../results/stability_rate/recipe_graph3.val.gpt-4o-mini.cert_granular_temp0_nonexact.p0.95.no_cot'

# %%
from tqdm.auto import tqdm
import json
import random
import time

total = len(dataset)
if debug:
    total = min(total, 5)
    
for di in tqdm(range(total)):
    data_entry = dataset[di]
    if os.path.exists(os.path.join(results_dir, f'{di}.json')):
        continue
    results_all = stability_scorer.get_stability_rate(data_entry)
    
    results_save = results_all._asdict()
    for i in range(len(results_save['stab_rate_results'])):
        results_save['stab_rate_results'][i]['stab_rate_results']['entailment_mode'] = suffix
    
    # sleep_duration = random.uniform(0.5, 2)
    # time.sleep(sleep_duration)
    
    with open(os.path.join(results_dir, f'{di}.json'), 'wt') as output_file:
        json.dump(results_save, output_file, indent=4)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3969880/3412569590.py in <module>
#      12     if os.path.exists(os.path.join(results_dir, f'{di}.json')):
#      13         continue
# ---> 14     results_all = stability_scorer.get_stability_rate(data_entry)
#      15
#      16     results_save = results_all._asdict()
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/methods/cert_nonexact.py in get_stability_rate(self, input_dict)
#      25         else:
#      26             num_raw = 0
# ---> 27         stab_rate_results_all_hyps = tree_stability_rate_deterministic(
#      28             self.entailment_model,
#      29             input_dict['ent_inputs'],
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/methods/utils/stability_deterministic.py in tree_stability_rate_deterministic(entailment_model, stab_inputs, children, parents, exact, p, epsilon, delta, entailment_mode, num_raw, temperature)
#     187     for ii in range(len(stab_inputs)):
#     188
# --> 189         stab_rate_results = stability_rate_deterministic(entailment_model, **stab_inputs[ii],
#     190                                            p=p, epsilon=epsilon,
#     191                                            delta=delta, return_all=True, samples=samples,
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/methods/utils/stability_deterministic.py in stability_rate_deterministic(f, premises, hypothesis, p, epsilon, delta, batch_size, return_all, verbose, samples, counts, exact, entailment_mode, N, num_raw, temperature)
#     100
#     101     # reference prediction
# --> 102     y = f([premises], [hypothesis], [s], mode=entailment_mode, temperature=temperature) # can we cache this?
#     103
#     104     if N is None:
#
# /opt/conda/envs/rapids/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /opt/conda/envs/rapids/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/models/entailment_model.py in forward(self, premises, hypothesis, s, return_all, temperature, mode, num_raw)
#     376                 pbar = tqdm(pbar)
#     377             for i in pbar:
# --> 378                 raw_outputs.extend(self.llm.generate(
#     379                     prompts[i:i+self.batch_size],
#     380                     max_new_tokens=self.max_new_tokens,
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/models/openai_llm.py in generate(self, prompts, max_new_tokens, temperature, **kwargs)
#      96         kwargs["max_tokens"] = max_new_tokens
#      97
# ---> 98         return self.batch_generate(prompts, batch_size=len(prompts),
#      99                                  temperature=temperature,
#     100                                  **kwargs)
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/models/openai_llm.py in batch_generate(self, prompts, batch_size, verbose, temperature, **kwargs)
#     144
#     145             with concurrent.futures.ThreadPoolExecutor(max_workers=batch_size) as executor:
# --> 146                 futures = [executor.submit(self.single_generate, prompt, **params) for prompt in batch]
#     147                 for f in futures: # this is to avoid the issue of the futures not being completed in order
#     148                     try:
#
# /shared_data0/weiqiuy/ares/notebooks/../src/exp_helpers/models/openai_llm.py in <listcomp>(.0)
#     144
#     145             with concurrent.futures.ThreadPoolExecutor(max_workers=batch_size) as executor:
# --> 146                 futures = [executor.submit(self.single_generate, prompt, **params) for prompt in batch]
#     147                 for f in futures: # this is to avoid the issue of the futures not being completed in order
#     148                     try:
#
# /opt/conda/envs/rapids/lib/python3.10/concurrent/futures/thread.py in submit(self, fn, *args, **kwargs)
#     174
#     175             self._work_queue.put(w)
# --> 176             self._adjust_thread_count()
#     177             return f
#     178     submit.__doc__ = _base.Executor.submit.__doc__
#
# /opt/conda/envs/rapids/lib/python3.10/concurrent/futures/thread.py in _adjust_thread_count(self)
#     197                                        self._initializer,
#     198                                        self._initargs))
# --> 199             t.start()
#     200             self._threads.add(t)
#     201             _threads_queues[t] = self._work_queue
#
# /opt/conda/envs/rapids/lib/python3.10/threading.py in start(self)
#     938                 del _limbo[self]
#     939             raise
# --> 940         self._started.wait()
#     941
#     942     def run(self):
#
# /opt/conda/envs/rapids/lib/python3.10/threading.py in wait(self, timeout)
#     605             signaled = self._flag
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#     609
#
# /opt/conda/envs/rapids/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Look at the results

# %%
di = 0

load_path = os.path.join(results_dir, f'{di}.json')
with open(load_path, 'rt') as input_file:
    results = json.load(input_file)

base_claims = dataset[di]['raw_claims']
derived_claims = dataset[di]['derived_claims']

# %%
results['stability_rates'], len(results['stability_rates']), len(derived_claims)
# Out:
# ([0.962598443031311,
#   0.9960628747940063,
#   0.9803148508071899,
#   0.9625983834266663,
#   0.960629940032959,
#   0.9999998807907104,
#   0.9999998807907104,
#   0.9999998807907104],
#  8,
#  8)

# %%
print("=== Base Claims ===")
for i, claim in enumerate(base_claims, 1):
    print(f"{i:2d}. {claim}")

print("\n=== Derived Claims with Stability Rates ===")
for i, (claim, rate) in enumerate(zip(derived_claims, results['stability_rates']), 1):
    print(f"{i:2d}. [{rate:.2f}] {claim}")
# Out:
# === Base Claims ===
#  1. A kinetic energy cutoff of 40 Ry for the wave function and of 240 Ry for the density together with a (10 × 10 × 12) Monkhorst–Pack k-point grid were used in geometry optimization; a (12 × 12 × 16) k-point grid was instead used for density of states calculations. Since IrO2 is a metal, we applied the Marzari-Vanderbilt cold smearing (22) of 0.02 Ry to the computed eigenvalues so as to improve the k-point convergence of our calculations.
#  2. We mentioned already the different demands for sampling density in semiconducting vs. metallic systems. Even if a material is semiconducting in the bulk, it may possess surface or interface states that are metallic.
#  3. Interestingly, transition metals require more k-points in general, independently from being part of a metallic (Fig. 6c) or of a non-metallic (Fig. 6d) system.
#  4. A baseline k-point mesh of 1000/(number of atoms in the cell) is used for all computations... As mentioned, we currently employ a k-point mesh of 1000 per reciprocal atom (pra).
#  5. For bulk calculations, a 4 × 4 × 4 Monkhorst-Pack grid of k-points [24] was chosen.
#  6. Metallic systems require accurate Fermi surface sampling, which necessitates denser k-point grids compared to insulators with band gaps
#  7. The tetragonal symmetry of rutile (space group P42/mnm) with c/a ≈ 0.64 suggests anisotropic electronic structure requiring different k-point densities along different directions
#  8. The comparison between insulating rutile structures using 4×4×4 grids and metallic IrO2 using 10×10×12 or denser grids demonstrates the inadequacy of 5×5×5 for metallic rutile IrO2
#  9. Based on convergence studies showing that metals require k-point densities sufficient to achieve <1 meV/atom accuracy, a 5×5×5 grid for metallic IrO2 would likely produce errors exceeding acceptable thresholds
#
# === Derived Claims with Stability Rates ===
#  1. [0.96] The claim that a 5x5x5 k-point grid is sufficient for converged DFT energy calculations of rutile-IrO2 bulk is extremely infeasible.
#  2. [1.00] Published DFT studies on rutile IrO2 employ significantly denser k-point grids, with 10×10×12 for geometry optimization and 12×12×16 for density of states calculations.
#  3. [0.98] IrO2 is a metallic conductor, which requires denser k-point sampling compared to insulators due to the need to accurately capture the Fermi surface.
#  4. [0.96] Transition metal compounds generally require higher k-point densities regardless of whether they are metallic or non-metallic.
#  5. [0.96] The rutile structure has tetragonal symmetry (a=b≠c), which typically requires different k-point densities along different crystallographic directions.
#  6. [1.00] Materials Project uses a baseline of 1000 k-points per reciprocal atom for transition metal oxides, which would translate to much denser grids than 5×5×5 for a 6-atom rutile unit cell.
#  7. [1.00] Even for insulating rutile structures, coarser grids like 4×4×4 are considered minimal, and metallic systems require significantly denser sampling.
#  8. [1.00] A 5×5×5 grid would likely result in errors of several meV/atom or more, which is insufficient for reliable total energy calculations.

# %%
import pandas as pd

# Base claims DataFrame
df_base = pd.DataFrame({
    "Index": range(1, len(base_claims) + 1),
    "Base Claim": base_claims
})

# Derived claims with stability rates DataFrame
df_derived = pd.DataFrame({
    "Index": range(1, len(derived_claims) + 1),
    "Stability Rate": results['stability_rates'],
    "Derived Claim": derived_claims
})

# Display nicely
print("=== Base Claims ===")
display(df_base)

print("\n=== Derived Claims with Stability Rates ===")
display(df_derived.style.format({"Stability Rate": "{:.2f}"}))
# Out:
# === Base Claims ===
#    Index                                         Base Claim
# 0      1  A kinetic energy cutoff of 40 Ry for the wave ...
# 1      2  We mentioned already the different demands for...
# 2      3  Interestingly, transition metals require more ...
# 3      4  A baseline k-point mesh of 1000/(number of ato...
# 4      5  For bulk calculations, a 4 × 4 × 4 Monkhorst-P...
# 5      6  Metallic systems require accurate Fermi surfac...
# 6      7  The tetragonal symmetry of rutile (space group...
# 7      8  The comparison between insulating rutile struc...
# 8      9  Based on convergence studies showing that meta...
# === Derived Claims with Stability Rates ===
# <style type="text/css">
# </style>
# <table id="T_20e7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20e7c_level0_col0" class="col_heading level0 col0" >Index</th>
#       <th id="T_20e7c_level0_col1" class="col_heading level0 col1" >Stability Rate</th>
#       <th id="T_20e7c_level0_col2" class="col_heading level0 col2" >Derived Claim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20e7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20e7c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_20e7c_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_20e7c_row0_col2" class="data row0 col2" >The claim that a 5x5x5 k-point grid is sufficient for converged DFT energy calculations of rutile-IrO2 bulk is extremely infeasible.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20e7c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_20e7c_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_20e7c_row1_col2" class="data row1 col2" >Published DFT studies on rutile IrO2 employ significantly denser k-point grids, with 10×10×12 for geometry optimization and 12×12×16 for density of states calculations.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20e7c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_20e7c_row2_col1" class="data row2 col1" >0.98</td>
#       <td id="T_20e7c_row2_col2" class="data row2 col2" >IrO2 is a metallic conductor, which requires denser k-point sampling compared to insulators due to the need to accurately capture the Fermi surface.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20e7c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_20e7c_row3_col1" class="data row3 col1" >0.96</td>
#       <td id="T_20e7c_row3_col2" class="data row3 col2" >Transition metal compounds generally require higher k-point densities regardless of whether they are metallic or non-metallic.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20e7c_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_20e7c_row4_col1" class="data row4 col1" >0.96</td>
#       <td id="T_20e7c_row4_col2" class="data row4 col2" >The rutile structure has tetragonal symmetry (a=b≠c), which typically requires different k-point densities along different crystallographic directions.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20e7c_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_20e7c_row5_col1" class="data row5 col1" >1.00</td>
#       <td id="T_20e7c_row5_col2" class="data row5 col2" >Materials Project uses a baseline of 1000 k-points per reciprocal atom for transition metal oxides, which would translate to much denser grids than 5×5×5 for a 6-atom rutile unit cell.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20e7c_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_20e7c_row6_col1" class="data row6 col1" >1.00</td>
#       <td id="T_20e7c_row6_col2" class="data row6 col2" >Even for insulating rutile structures, coarser grids like 4×4×4 are considered minimal, and metallic systems require significantly denser sampling.</td>
#     </tr>
#     <tr>
#       <th id="T_20e7c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20e7c_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_20e7c_row7_col1" class="data row7 col1" >1.00</td>
#       <td id="T_20e7c_row7_col2" class="data row7 col2" >A 5×5×5 grid would likely result in errors of several meV/atom or more, which is insufficient for reliable total energy calculations.</td>
#     </tr>
#   </tbody>
# </table>
